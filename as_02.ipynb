# %% [markdown]
# ### $\color{indianred}{\text{ASTROSTATISTIKA - v2}} $
#
# <hr style="border: none; height: 2px; background-color: indianred; opacity: 0.5;" />

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import NullFormatter
import matplotlib
from scipy.stats import uniform, norm, laplace, cauchy, cosine, lognorm, mode, skew, kurtosis, gaussian_kde, sem
from tqdm import tqdm
matplotlib.rcParams.update({"text.usetex": False, "font.size" : 10, "font.family": "monospace"})

# %% [markdown]
# Svaka funkcija slučajne promjenjive je sama po sebi slučajna promjenjiva. U praksi se često mjeri vrijednost varijable $x$, ali od interesa je poznavati neku
#
# funkciju $y(x)$. Ukoliko je data raspodjela gustine vjerovatnoće $p(x)$, želimo da pređemo na $p(y)$. Ako pretpostavimo da možemo pisati $y=\Phi(x)$, uz
#
# to da važi $x=\Phi^{-1}(y)$, slijedi jednačina:
#
# $$
# p(y)=p\big[\Phi^{-1}(y)\big]\Big|\frac{d \Phi^{-1}(y)}{dy}\Big|.
# $$
#
# $\blacksquare$ **P1**: Ako je $y=e^x$, onda je $x=\ln(y)$. Sa $p(x)=1$ za $0\leq x\leq1$ i $p(x)=0$ inače (uniformna raspodjela), dobijamo da je $p(y)=\frac{1}{y}$ za $1\leq y\leq e$
#
# i $p(y)=0$ inače. Dakle, sa uniformne raspodjele po $x$ prešli smo na neuniformnu raspodjelu po $y$.

# %%
np.random.seed(0)

uniformna_raspodjela = uniform(0,1)
x_uzorak = uniformna_raspodjela.rvs(1000)
x = np.linspace(-0.5, 1.5, 1000)
px = uniformna_raspodjela.pdf(x)

y_uzorak = np.exp(x_uzorak)
y = np.exp(x)
py = px / y

# %%
plt.figure(figsize=(12, 5))
plt.subplot(121)
plt.hist(x_uzorak, bins=50, label=r'uzorak iz $\mathcal{U}(0,1)$', histtype='step', color='black', density=True)
plt.plot(x, px, label=r'PDF od $\mathcal{U}(0,1)$', color='indianred')
plt.xlabel(r'$x$')
plt.ylabel(r'$p(x)$')
plt.legend()
plt.subplot(122)
plt.hist(y_uzorak, bins=50, label=r'uzorak iz $y = e^x$', histtype='step', color='black', density=True)
plt.plot(y, py, label=r'PDF od $p(y) = p(\ln y)|\frac{dx}{dy}|$', color='indianred')
plt.xlabel(r'$y$')
plt.ylabel(r'$p(y)$')
plt.legend()
plt.suptitle(r'Primjer transformacije slučajne varijable: $y = e^x$')
plt.tight_layout()
plt.show()

# %% [markdown]
# <hr style="border: none; height: 2px; background-color: magenta; opacity: 0.5;" />
#
# $\color{magenta}{\text{Z1}}$ : Važi $y=x^2$ uz $x\sim\mathcal{U}(-1,1)$ i $p(x)=1/2$. Naći $p(y)$.
#
# <hr style="border: none; height: 2px; background-color: magenta; opacity: 0.5;" />
#
# $\color{magenta}{\text{R1}}$: Možemo pisati:
#
# $$
# x = \pm\sqrt{y},\, y \in [0, 1].
# $$
#
# $\Phi$ nije monotona, te treba *sabrati* doprinos obje strane:
# $$
# p(y) = p(\sqrt{y})\left|\frac{d\sqrt{y}}{dy}\right| + p(-\sqrt{y})\left|\frac{d(-\sqrt{y})}{dy}\right| = \frac{1}{2} \cdot \frac{1}{2\sqrt{y}} + \frac{1}{2} \cdot \frac{1}{2\sqrt{y}} = \frac{1}{2\sqrt{y}}, \quad y \in [0, 1].
# $$
#
# Verifikaciju vršimo provjerom normalizacije:
#
# $$
# \int_0^1 \frac{1}{2\sqrt{y}}\,dy = \left[\sqrt{y}\right]_0^1 = 1.
# $$

# %%
np.random.seed(0)

uniformna_raspodjela = uniform(-1, 2)  # U(-1, 1)
x_uzorak = uniformna_raspodjela.rvs(1000)
x = np.linspace(-1.5, 1.5, 1000)
px = uniformna_raspodjela.pdf(x)

y_uzorak = x_uzorak**2
y = np.linspace(0, 1, 1000)[1:]  
py = 1 / (2 * np.sqrt(y))

plt.figure(figsize=(12, 5))
plt.subplot(121)
plt.hist(x_uzorak, bins=50, label=r'uzorak iz $\mathcal{U}(-1,1)$', histtype='step', color='grey', density=True)
plt.plot(x, px, label=r'PDF od $\mathcal{U}(-1,1)$', color='indianred')
plt.xlabel(r'$x$')
plt.ylabel(r'$p_x(x)$')
plt.legend()
plt.subplot(122)
plt.hist(y_uzorak, bins=50, label=r'uzorak iz $y = x^2$', histtype='step', color='grey', density=True)
plt.plot(y, py, label=r'PDF od $p(y) = p(\sqrt{y})|\frac{dx}{dy}|$', color='indianred')
plt.xlabel(r'$y$')
plt.ylabel(r'$p(y)$')
plt.legend()
plt.suptitle(r'Primjer transformacije slučajne varijable: $y = x^2$')
plt.tight_layout()
plt.show()

# %% [markdown]
# Šta ako želimo da *propagiramo* neodređenost od $x$ do $y=\Phi(x)$? Tejlorov razvoj $\Phi$ oko $x_0$ jeste:
#
# $$
# \Phi(x) = \Phi(x_0) + \frac{d\Phi}{dx}\Big|_0 (x - x_0) + \frac{1}{2}\frac{d^2\Phi}{dx^2}\Big|_0 (x-x_0)^2 + \cdots
# $$
#
# Zadržava se samo član prvog reda:
#
# $$
# \Phi(x) \approx \Phi(x_0) + \frac{d\Phi}{dx}\Big|_0 (x - x_0).
# $$
#
# Sada je devijacija $y$ od $y_0$ aproksimativno:
#
# $$
# y - y_0 \approx\frac{d\Phi}{dx}\Big|_0 (x - x_0).
# $$
#
# Koristeći pravilo za varijansu $V(Cx)=C^2V(x)$, uz to da sada imamo $V(y) = \left(\frac{d\Phi}{dx}\Big|_0\right)^2 V(x)$, može se pisati (preko $\sigma=\sqrt{V}$):
#
# $$
# \sigma_y = \left|\frac{d\Phi}{dx}\right|_0 \sigma_x.
# $$
#
# Ako je izmjerena vrijednost $x_0$, sa neodređenošću od $\sigma_x$, onda se može procijeniti neodređenost za $y$, tj. neko $\sigma_y$ za $y_0=\Phi(x_0)$.
#
# $\blacksquare$ **P2**: Mjerenja fluksa odgovaraju gausovskoj raspodjeli sa malom relativnom greškom, što korespondira tome da će raspodjela magnituda biti približno gausovska.
#
#  Međutim, ukoliko mjerenja fluksa imaju veću relativnu grešku, to će biti povezano sa asimetričnom negausovskom raspodjelom magnituda. Može se pisati jednakost:
#
#
# $$
# m=-2.5\log_{10}(F),
# $$
#
# gdje će od koristi biti $F=10^{-m/2.5}=e^{-m\ln10/2.5}$, uz $\frac{dF}{dm}=-\frac{\ln10}{2.5}10^{-m/2.5}$. Takođe, važi $p(m)=p(F)\big|\frac{dF}{dm}\big|$.
#
# Moguća je diskretna aproksimacija ako pišemo:
#
# $$
# \Big|\frac{\Delta F}{\Delta m}\Big|\approx\frac{|F_i-F_{i-1}|}{|m_i-m_{i-1}|}\implies p(m_i)=p(F_i)\Big|\frac{\Delta F_i}{\Delta m_i}\Big|.
# $$

# %%
np.random.seed(1)

raspodjela = norm(1, 0.01) # normalna raspodjela: sr. vrijednost 1, neodređenost 1%
fluks = raspodjela.rvs(10000) # uzorkovanje 10000 vrijednosti fluksa iz raspodjele
fluks_fit = np.linspace(0.001, 2, 1000) # za crtanje glatke krive
pdf_fluks_fit = raspodjela.pdf(fluks_fit) # računanje PDF-a raspodjele na fit liniji

mag = -2.5 * np.log10(fluks) # transformacija uzorkovanih vrijednosti fluksa u magnitude
mag_fit = -2.5 * np.log10(fluks_fit) # transformacija za liniju "fita"
pdf_mag_fit = pdf_fluks_fit.copy()
pdf_mag_fit[1:] /= abs(mag_fit[1:] - mag_fit[:-1]) # diskretna aproksimacija 
pdf_mag_fit /= np.dot(pdf_mag_fit[1:], abs(mag_fit[1:] - mag_fit[:-1])) # normalizacija

# %% [markdown]
# U posljednjoj liniji (normalizacija: $\int p(m)dm=1$) je iskorišćen `np.dot(a,b)` (koji zapravo radi sumiranje proizvoda $\sum_i a_ib_i$) što daje:
#
# $$
# \int p(m)dm\approx\sum_i p(m_i)|\Delta m_i|.
# $$

# %%
raspodjela25 = norm(1, 0.25) # sve isto, ali sa neodređenošću od 25% 
fluks25 = raspodjela25.rvs(10000)
fluks_fit25 = np.linspace(0.001, 2, 1000)
pdf_fluks_fit25 = raspodjela25.pdf(fluks_fit25)

mag25 = -2.5 * np.log10(fluks25)
mag_fit25 = -2.5 * np.log10(fluks_fit25)
pdf_mag_fit25 = pdf_fluks_fit25.copy()
pdf_mag_fit25[1:] /= abs(mag_fit25[1:] - mag_fit25[:-1])
pdf_mag_fit25 /= np.dot(pdf_mag_fit25[1:], abs(mag_fit25[1:] - mag_fit25[:-1]))

# %% [markdown]
# Treba napomenuti da se ovdje radi o tzv. $4-\sigma$ detekcionom limitu:
#
# $$
# \text{SNR} = \frac{F}{\sigma_F} = \frac{1}{0.25} = 4,
# $$
#
# gdje je definisan *Signal-to-Noise Ratio*. Dakle, signal je $4$ standardne devijacije iznad nule. Takođe, važiće:
#
# $$
# \mathbb{E}[\log F] \neq \log(\mathbb{E}[F]),
# $$
#
# t.d. $\langle m\rangle\neq-2.5\log_{10}(\langle F\rangle)$. Medijane pak korespondiraju:
#
# $$
# m_{1/2} = -2.5\log_{10}(F_{1/2}).
# $$
#
# Napomena: $\mathbb{E}$ označava očekivanu vrijednost i važi  $\mathbb{E}[F] = \int F \, p(F) \, dF$.

# %%
plt.figure(figsize=(12,10))
plt.subplot(221)
plt.plot(fluks_fit, pdf_fluks_fit, label=r'PDF od $\mathcal{N}(1, 0.01)$', color='indianred')
plt.hist(fluks, bins=np.linspace(0.75, 1.25, 50), label=r'uzorak iz $\mathcal{N}(1, \sigma=0.01)$', histtype='step', color='grey', density=True)
plt.axvline(1, color='gray', linestyle=':')
plt.xlabel(r'$F$')
plt.ylabel(r'$p(F)$')
plt.xlim(0.75, 1.25)
plt.legend()
plt.subplot(222)
plt.plot(mag_fit, pdf_mag_fit, label=r'PDF od $p(m) = p(10^{-0.4m})|dF/dm|$', color='indianred')
plt.hist(mag, bins=np.linspace(-0.25, 0.25, 50), label=r'uzorak iz $m = -2.5\log_{10} F$', histtype='step', color='grey', density=True)
plt.axvline(0, color='gray', linestyle=':')
plt.xlabel(r'$m$')      
plt.ylabel(r'$p(m)$')
plt.xlim(-0.25, 0.25)
plt.legend()        
plt.subplot(223)
plt.plot(fluks_fit25, pdf_fluks_fit25, label=r'PDF od $\mathcal{N}(1, \sigma=0.25)$', color='indianred')
plt.hist(fluks25, bins=np.linspace(0, 2, 50), label=r'uzorak iz $\mathcal{N}(1, 0.25)$', histtype='step', color='grey', density=True) 
plt.axvline(1, color='gray', linestyle=':')
plt.xlabel(r'$F$')
plt.ylabel(r'$p(F)$')
plt.xlim(0, 2)
plt.legend()
plt.subplot(224)
plt.plot(mag_fit25, pdf_mag_fit25, label=r'PDF od $p(m) = p(10^{-0.4m})|dF/dm|$', color='indianred')
plt.hist(mag25, bins=np.linspace(-1, 1, 50), label=r'uzorak iz $m = -2.5\log_{10} F$', histtype='step', color='grey', density=True)
plt.axvline(0, color='gray', linestyle=':')
plt.xlabel(r'$m$')
plt.ylabel(r'$p(m)$')
plt.xlim(-1, 1)
plt.legend()            
plt.suptitle(r'Gausijan fluksa za velike neodređenosti postaje negausovska funkcija magnitude ($m = -2.5\log_{10} F$)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# Od koristi je kratko se osvrnuti na **Monte Karlo** integraciju. Ako imamo komplikovan integral koji se može zapisati kao $\int f(x)p(x)dx$, gdje se $f(x)$ evaluira, a $p(x)$
#
# uzorkuje (uz $\int p(x)dx=1$), onda se može pisati:
#
#
# $$
# \int f(x)p(x)dx \approx \frac{1}{N}\sum_{i=1}^{N}f(x_i),
# $$
#
# gdje su $x_i$ uzorci izvučeni iz $p(x)$.
#
# $\blacksquare$ **P3**: Treba riješiti integral:
#
# $$
# I=\int_{0.3}^{4}\frac{e^x\sqrt{4x+3}\ln(x^6)}{\tanh(x)}dx.
# $$
#
# Ukoliko uzmemo da je $p(x)=\frac{1}{4-0.3}$ i da je $f(x)=\frac{e^x\sqrt{4x+3}\ln(x^6)}{\tanh(x)}$, onda imamo:
#
# $$
# I=(4-0.3)\int_{0.3}^{4}\frac{1}{(4-0.3)}\frac{e^x\sqrt{4x+3}\ln(x^6)}{\tanh(x)}dx.
# $$
#
# Primijetimo da je $p(x)$ uniformna raspodjela. Sada treba uzorkovati iz $p$, ubaciti u $f$ i sumirati.

# %%
xmax = 4
xmin = 0.3

xi = np.random.uniform(xmin, xmax, 1000)

def fun(x):
    return np.exp(x)*(4*x+3)**0.5 * np.log(x**6)/np.tanh(x)

integral = (xmax - xmin) * np.mean(fun(xi))
print('I =', integral)
# Out:
# I = 1412.5283235646893

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <hr style="border: none; height: 2px; background-color: magenta; opacity: 0.5;" />
#
# $\color{magenta}{\text{Z2}}$ : Koristeći Monte Karlo metodu, pokazati da je:
#
# $$
# \int_0^\infty x^3e^{-\frac{x^2}{2\sigma^2}}dx=2\sigma^4.
# $$
#
# Kako rezultat zavisi od broja uzoraka? Da li se greška smanjuje?
#
# <hr style="border: none; height: 2px; background-color: magenta; opacity: 0.5;" />
#
# $\color{magenta}{\text{R2}}$ :
#
# PDF za Gausijan sa $\mu=0$ je oblika $p(x)=\frac{1}{\sigma\sqrt{2\pi}}e^{-\frac{x^2}{2\sigma^2}}$, i on je normalizovan za ($-\infty,+\infty$). Nama je potrebna polovina Gausijana, normalizovana na ($0,+\infty$):
#
#
# $$
# p(x) = \frac{2}{\sigma\sqrt{2\pi}}e^{-\frac{x^2}{2\sigma^2}}.
# $$
#
# Sada, integral postaje:
#
# $$
# I = \int_0^\infty x^3 e^{-\frac{x^2}{2\sigma^2}}dx = \sigma\sqrt{\frac{\pi}{2}} \int_0^\infty x^3 \frac{2}{\sigma\sqrt{2\pi}}e^{-\frac{x^2}{2\sigma^2}}\,dx = \sigma\sqrt{\frac{\pi}{2}}\,\mathbb{E}[x^3],
# $$
#
# gdje je upotrijebljena jednakost $\mathbb{E}[x^3] = \int_0^\infty x^3 p(x)\,dx$. Monte Karlo aproksimacija daje:
#
# $$
# I \approx \sigma\sqrt{\frac{\pi}{2}} \cdot \frac{1}{N}\sum_{i=1}^N x_i^3, \quad x_i \sim p(x).
# $$

# %%
sigma = 2
N = 1000
gausijan = norm(loc=0, scale=sigma)
uzorci = np.abs(gausijan.rvs(N))

plt.figure(figsize=(12,5))
plt.subplot(121)
plt.hist(gausijan.rvs(N), density=True, bins=50, label=r'uzorak iz $N(0, \sigma^2)$', histtype='step', color='grey')
plt.plot(np.linspace(-3*sigma, 3*sigma, 100), gausijan.pdf(np.linspace(-3*sigma, 3*sigma, 100)), label=r'PDF od $N(0, \sigma^2)$', color='indianred')
plt.legend()
plt.subplot(122)
plt.hist(uzorci, density=True, bins=50, label=r'uzorak iz $|N(0, \sigma^2)|$', histtype='step', color='grey');
plt.plot(np.linspace(0, 3*sigma,100), 2*gausijan.pdf(np.linspace(0,3*sigma,100)), label=r'PDF od $|N(0, \sigma^2)|$', color='indianred')
plt.legend()
plt.suptitle('Zadatak 2a.')
plt.tight_layout()
plt.show()

I = sigma*(np.pi/2)**0.5 * np.mean(uzorci**3)
poznat_rezultat = 2*sigma**4 

print('I:', I, '| Poznat rezultat:', poznat_rezultat, '| Relativna greška:', np.round(np.abs(I - poznat_rezultat) / poznat_rezultat, 4))
# Out:
# I: 32.877636314581444 | Poznat rezultat: 32 | Relativna greška: 0.0274

# %%
def integral(sigma, N):
    gausijan = norm(loc=0, scale=sigma)
    uzorci = np.abs(gausijan.rvs(N))
    n = sigma*(np.pi/2)**0.5
    return n * np.mean(uzorci**3) 

def poznat_rezultat(sigma):
    return 2*sigma**4  

sigma = 0.45
Nvals = np.unique(np.logspace(0,6,100,dtype=int))
rezultati = np.array([integral(sigma, N) for N in tqdm(Nvals)])
# Out:
# 100%|██████████| 92/92 [00:00<00:00, 130.32it/s]

# %%
plt.figure(figsize=(12,5))
plt.subplot(121) 
plt.axhline(poznat_rezultat(sigma), color='indianred')
plt.plot(Nvals, rezultati, color='grey')
plt.title('Konvergencija rezultata')
plt.loglog()

plt.subplot(122)
plt.axhline(0, color='indianred')
plt.plot(Nvals, (rezultati - poznat_rezultat(sigma))/poznat_rezultat(sigma), color='grey')
plt.plot(Nvals,  Nvals**-0.5, color='springgreen', linestyle=':')
plt.plot(Nvals, -Nvals**-0.5, color='springgreen', linestyle=':')
plt.xscale('log')
plt.title(r'Relativna greška ($1/\sqrt{N}$)')
plt.suptitle('Zadatak 2b.')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# Funkcija raspodjele $h(x)$ može se okarakterisati parametrima *lokacije*, *skale* i *oblika* - ti parametri čine **deskriptivnu statistiku**. Oni mogu *opisivati* analitičku
# funkciju
#
# raspodjele $h(x)$ (statistika populacije) ili procjenu $h(x)$ dobijenu iz podataka - neku funkciju $f(x)$ (tada se govori o uzoračkoj statistici - postoji konačan skup podataka).
#
# Ispod su prikazani najvažniji parametri.
#
#
# - aritmetička srednja vrijednost (očekivana vrijednost) pokazuje gdje je locirano najviše gustine raspodjele:
#
# $$
# \mu= \mathbb{E}(x)=\int_{-\infty}^{\infty}xh(x)dx,
# $$
#
# - varijansa (ranije označavano kao Var) pokazuje koliko je široka raspodjela:
#
# $$
# V=\int_{-\infty}^{\infty}(x-\mu)^2h(x)dx,
# $$
#
# - standardna devijacija (korisna jer ima iste jedinice kao $\mu$):
#
# $$
# \sigma=\sqrt{V},
# $$
#
# - mjera asimetrije (*skewness*) pokazuje asimetričnost raspodjele (simetrične raspodjele nemaju *skewness*):
#
# $$
# \Sigma=\int_{-\infty}^{\infty}\Big(\frac{x-\mu}{\sigma}\Big)^3h(x)dx,
# $$
#
# - mjera zaobljenosti (*kurtosis*) pokazuje da li su podaci oštrije ili spljoštenije raspoređeni u odnosu na $\mathcal{N}$:
#
# $$
# K=\int_{-\infty}^{\infty}\Big(\frac{x-\mu}{\sigma}\Big)^4h(x)dx-3,
# $$
#
# - apsolutna devijacija predstavlja srednju udaljenost između tačke $d$ i srednje vrijednosti:
#
# $$
# \delta = \int_{-\infty}^{\infty} |x - d|h(x)dx,
# $$
#
# - moda je parametar lokacije koji odgovara najvjerovatnijim vrijednostima (nije najpouzdaniji parametar):
#
# $$
# \left(\frac{dh(x)}{dx}\right)_{x_m} = 0,
# $$
#
# - percentili/kvantili su segmenti koji dijele opsjeg raspodjele vjerovatnoće u kontinualne intervale jednakih vjerovatnoća (npr. $q_{50}$ - medijana):
#
# $$
# \frac{p}{100} = \int_{-\infty}^{q_p} h(x) dx.
# $$
#
# **Važno**: U jednačini iznad je upotrijebljena još jedna važna veličina *Cumulative Distribution Function* (CDF):
#
# $$
# F(x) = \int_{-\infty}^{x} p(x)\,dx.
# $$
#
# Dakle, $F(x)$ daje odgovor na pitanje koja je vjerovatnoća da slučajna varijabla uzima vrijednosti $\leq x$.
#
# Kad se radi sa malim brojem uzoraka nužno je biti oprezan pri korišćenju momenata višeg reda (*osjetljivost* na odstupajuće vrijednosti). Momenti (reda $n$) su $V$, $\Sigma$ i $K$ jer su
#
# definisani preko $\int_{-\infty}^{\infty}\Big(\frac{x-\mu}{\sigma}\Big)^nh(x)dx$. Valja takođe napomenuti i da neke raspodjele nemaju konačnu varijansu (npr. Košijeva), te će *skewness* i *kurtosis* za njih divergirati.
#
# Varijansa ($n=2$) postoji ako repovi raspodjele opadaju brže od $|x|^{-3}$, a Košijeva raspodjela ima repove koji prate $|x|^{-2}$.

# %% [markdown]
# $\blacksquare$ **P4**: Nalazimo $\Sigma$ i $K$ za različite raspodjele.

# %%
uni = uniform.stats(moments = 'k') # kurtosis uniformne raspodjele
lap = laplace.stats(moments = 'k') # kurtosis Laplasove raspodjele
cos = cosine.stats(moments = 'k') # kurtosis kosinusne raspodjele
logn = lognorm.stats(1.2, moments = 's') # skewness lognormalne raspodjele
gaus = norm.stats(moments = 'sk') # skewness i kurtosis normalne raspodjele
skew_gaus = gaus[0]
kurt_gaus = gaus[1]

x = np.linspace(-8, 8, 1000)
N = norm(0, 1)

# %% [markdown]
# [DODATAK] Modifikovani Gausijan može se napraviti koristeći tzv. Gram-Šarlije razvoj:
#
# $$
# h(x)=\mathcal{N}(\mu,\sigma)\sum_{k=0}^\infty a_kH_k(z),
# $$
#
# $$
# \,a_0=2,\,a_1=1,\,a_2=1/2\,|\,H_0(z)=1,\,H_1(z)=z,\,H_2(z)=z^2-1\,|\,z=(x-\mu)/\sigma.
# $$

# %%
gaus_mod = 0.5 * N.pdf(x) * (2 + x + 0.5 * (x*x - 1)) # modifikovani gausijan - uvodi se polinomijalni faktor koji narušava simetriju 
dx = x[1] - x[0]
mu_mod = np.sum(x * gaus_mod) * dx
sigma_mod = np.sqrt(np.sum((x - mu_mod)**2 * gaus_mod) * dx)
skew_mod = np.sum(((x - mu_mod) / sigma_mod)**3 * gaus_mod) * dx

# %%
plt.figure(figsize=(12, 5))
plt.subplot(121)
plt.plot(x, N.pdf(x), color='grey', label=r'Gausijan $\Sigma={}$'.format(skew_gaus))
plt.plot(x, 0.5 * N.pdf(x) * (2 + x + 0.5 * (x * x - 1)), color='indianred', linestyle='--', label=r'mod. Gausijan, $\Sigma={}$'.format(round(skew_mod, 2)))
plt.plot(x[x>0], lognorm(1.2).pdf(x[x>0]), color='royalblue', linestyle=':', label=r'Log-normalna, $\Sigma={}$'.format(round(logn, 2)))
plt.xlabel(r'$x$')
plt.ylabel(r'$p(x)$')
plt.xlim(-5,5)
plt.ylim(0, 0.7)
plt.legend()

plt.subplot(122)
plt.plot(x, norm(0, 1).pdf(x), color='grey', linestyle='-', label=r'Gausijan, $K={}$'.format(round(kurt_gaus, 2)))
plt.plot(x, laplace(0, 1).pdf(x), color='indianred', linestyle='--', label=r'Laplasijan, $K={}$'.format(round(lap, 2)))
plt.plot(x, cosine(0, 1).pdf(x), color='royalblue', linestyle=':', label=r'Kosinusna, $K={}$'.format(round(cos, 2)))
plt.plot(x, uniform(-2, 4).pdf(x), color='springgreen', linestyle='-.', label=r'Uniformna, $K={}$'.format(round(uni, 2)))
plt.xlabel(r'$x$')
plt.ylabel(r'$p(x)$')
plt.xlim(-5,5)
plt.ylim(0, 0.55)
plt.legend(loc='upper left')
plt.suptitle(r'Primjeri različitih raspodjela i njihovih koeficijenata asimetrije $\Sigma$ i kurtosisa $K$')
plt.tight_layout()
plt.show()

# %% [markdown]
# Naravno, pored korisnih funkcionalnosti iz `SciPy`, postoje i odlične `NumPy` funkcije.

# %%
x = np.random.random(1000)*100

q25, q50, q75 = np.percentile(x, [25, 50, 75])
sv = np.mean(x)
medijana = np.median(x) 
varijansa = np.var(x) 
stdev = np.std(x)
s = skew(x)
k = kurtosis(x)
moda = mode(x)

print(f"25. percentil: {q25:.2f}")
print(f"50. percentil: {q50:.2f}")
print(f"75. percentil: {q75:.2f}")
print(f"Srednja vrijednost: {sv:.2f}")
print(f"Medijana: {medijana:.2f}")
print(f"Varijansa: {varijansa:.2f}")
print(f"Standardna devijacija: {stdev:.2f}")
print(f"Skewness: {s:.2f}")
print(f"Kurtosis: {k:.2f}")
print(f"Mod: {moda[0]:.2f}")
# Out:
# 25. percentil: 23.54
# 50. percentil: 50.38
# 75. percentil: 75.65
# Srednja vrijednost: 49.73
# Medijana: 50.38
# Varijansa: 841.99
# Standardna devijacija: 29.02
# Skewness: 0.02
# Kurtosis: -1.21
# Mod: 0.03

# %%
plt.figure(figsize=(12, 5))
plt.hist(x, bins=50, density=True, histtype='step', color='grey', label='uzorak')

plt.axvline(sv, color='indianred', linestyle='-', label=r'$\mu$ = {}'.format(round(sv, 2)))
plt.axvline(medijana, color='royalblue', linestyle='-', label=r'medijana = {}'.format(round(medijana, 2)))
plt.axvline(q25, color='springgreen', linestyle=':', label=r'$q_{{25}}$ = {}'.format(round(q25, 2)))
plt.axvline(q75, color='springgreen', linestyle='--', label=r'$q_{{75}}$ = {}'.format(round(q75, 2)))
plt.axvspan(q25, q75, alpha=0.2, color='springgreen', label='Interkvartilni opsjeg')

plt.xlabel(r'$x$')
plt.ylabel(r'$p(x)$')
plt.title('Deskriptivna statistika uzorka')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# <hr style="border: none; height: 2px; background-color: magenta; opacity: 0.5;" />
#
# $\color{magenta}{\text{Z3}}$ : Izračunati koeficijent asimetrije $\Sigma$ i kurtosis $K$ za sljedeće raspodjele: normalnu, asimetričnu, uniformnu i šiljastu raspodjelu. Uporediti i srednju vrijednost i medijanu.
#
# <hr style="border: none; height: 2px; background-color: magenta; opacity: 0.5;" />
#
# $\color{magenta}{\text{R3}}$ : Arbitrarno ćemo definisati prethodne funkcije.

# %%
normirana = np.random.normal(size=100000)
asimetricna = np.concatenate((np.random.normal(size=35000) + 2, np.random.exponential(size=65000)), axis=0)
uniformna = np.random.uniform(0, 2, size=100000)
siljasta = np.concatenate((np.random.exponential(size=50000), np.random.exponential(size=50000) * (-1)), axis=0)

# %%
x = np.linspace(-10, 10, 1000)

plt.figure(figsize=(12, 5))
plt.subplot(121)
plt.plot(x, gaussian_kde(normirana)(x), color='grey', label=r'Normalna, $\Sigma={}$, $K={}$'.format(round(skew(normirana), 2), round(kurtosis(normirana), 2)))
plt.plot(x, gaussian_kde(asimetricna)(x), color='indianred', label=r'Asimetrična, $\Sigma={}$, $K={}$'.format(round(skew(asimetricna), 2), round(kurtosis(asimetricna), 2)))
plt.axvline(np.mean(normirana), color='grey', linestyle=':', label=r'$\mu$ = {}'.format(round(np.mean(normirana), 2)))
plt.axvline(np.mean(asimetricna), color='indianred', linestyle=':', label=r'$\mu$ = {}'.format(round(np.mean(asimetricna), 2)))
plt.axvline(np.median(normirana), color='grey', linestyle='-.', label=r'medijana = {}'.format(round(np.median(normirana), 2)))
plt.axvline(np.median(asimetricna), color='indianred', linestyle='-.', label=r'medijana = {}'.format(round(np.median(asimetricna), 2)))    
plt.xlabel(r'$x$')
plt.ylabel(r'$p(x)$')
plt.legend()

plt.subplot(122)
plt.plot(x, gaussian_kde(uniformna)(x), color='royalblue', label=r'Uniformna, $\Sigma={}$, $K={}$'.format(round(skew(uniformna), 2), round(kurtosis(uniformna), 2)))
plt.plot(x, gaussian_kde(siljasta)(x), color='springgreen', label=r'Šiljasta, $\Sigma={}$, $K={}$'.format(round(skew(siljasta), 2), round(kurtosis(siljasta), 2)))
plt.axvline(np.mean(uniformna), color='royalblue', linestyle=':', label=r'$\mu$ = {}'.format(round(np.mean(uniformna), 2)))
plt.axvline(np.mean(siljasta), color='springgreen', linestyle=':', label=r'$\mu$ = {}'.format(round(np.mean(siljasta), 2)))
plt.axvline(np.median(uniformna), color='royalblue', linestyle='-.', label=r'medijana = {}'.format(round(np.median(uniformna), 2)))
plt.axvline(np.median(siljasta), color='springgreen', linestyle='-.', label=r'medijana = {}'.format(round(np.median(siljasta), 2)))
plt.xlabel(r'$x$')
plt.ylabel(r'$p(x)$')
plt.legend()

plt.suptitle(r'Primjeri različitih raspodjela i njihova deskriptivna statistika')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# Bilo koja od ovih veličina može biti određena direktno iz podataka (dakle, to je statistika uzorka, a ne populacije). Ukoliko je dato $N$ mjerenja $x_i$, $i=1,2,\dots N$,  integral oblika
#
# $\int_{-\infty}^{\infty}g(x)h(x)dx$ postaje $\frac{1}{N}\sum_{i=1}^Ng(x_i)$. Npr. jednakost za srednju vrijednost $\mu=\int_{-\infty}^{\infty}xh(x)dx$ se transformiše u $\bar{x}=\frac{1}{N}\sum_{i=1}^Nx_i$ (aritmetička srednja vrijednost uzorka);
#
# standardna devijacija od $\sigma=\sqrt{V}=\sqrt{\int_{-\infty}^{\infty}(x-\mu)^2h(x)dx}$ prelazi u $s=\sqrt{\frac{1}{N-1}\sum_{i=1}^N(x_i-\bar{x})^2}$. Faktor $N-1$ dolazi od činjenice da je $\bar{x}$ takođe određeno iz podataka.
#
# Ovo se naziva Beselova korekcija, te je $s^2$ nepristrasno, a $s$ je potcijenjeno (manje od $1\%$ za $N=30$).
#
#
# Dakle, $\mu$ i $\sigma$ dolaze od prave raspodjele $h(x)$, a $\bar{x}$ i $s$ su procjene bazirane na uzorku konačne veličine. Ove procjene imaju varijansu i pristrasnost (*bias*), koje se obično povezuju
#
# preko srednje kvadratne greške (*Mean Squared Errors*):
#
# $$
# \text{MSE}=V+\text{bias}^2,
# $$
#
# gdje je *bias* očekivana vrijednost razlike između procjene (*estimatora*) i istinite / prave vrijednosti. Konzistentni *estimatori* su oni čiji $V$ i *bias* iščezavaju kako $N\rightarrow\infty$.
#
# $\blacksquare$ **P5**: Uzorak koji ima *bias* potcjenjuje varijansu. Možemo demonstrirati tzv. Beselovu korekciju.

# %%
nepopravljeno = []
popravljeno = []
for x in range(1, 40000):
    uzorci = np.random.normal(loc=5.0, scale=1.0, size=5) # generisanje više N=5 uzoraka iz normalne raspodjele
    nepopravljeno.append(np.std(uzorci, ddof=0)) # sr. treba da bude "više" ispod 1; pristrasno, potcjenjuje standardnu devijaciju
    popravljeno.append(np.std(uzorci, ddof=1)) # dijeljenjem sa N-1 dobijamo nepristrasnu procjenu standardne devijacije, koja je bliža stvarnoj vrijednosti od 1.0

# ddof - degree of freedom: u ovom kontekstu znači "koliko postoji nezavisnih informacija za procjenu varijanse"
plt.figure(figsize=(12, 5))
plt.hist(nepopravljeno, bins=100, color='grey', lw=1.5, histtype='step', label=r'nepopravljeno: $\mu=$ {:.2f}'.format(np.mean(nepopravljeno)))
plt.hist(popravljeno, bins=100, color='indianred', lw=1.5, histtype='step', label=r'popravljeno: $\mu=$ {:.2f}'.format(np.mean(popravljeno)))
plt.axvline(np.mean(nepopravljeno), color='grey', linestyle=':', label=r'$s_n$')
plt.axvline(np.mean(popravljeno), color='indianred', linestyle=':', label=r'$s_p$')
plt.axvline(x=1, label=r'$\sigma$', color='springgreen')
plt.title("Beselova korekcija")
plt.xlabel(r"Standardna greška")
plt.ylabel("Broj uzoraka")
plt.legend()
plt.show()

# %% [markdown]
# Ako je $N>10$ (otprilike) i ako je varijansa od $h(x)$ konačna, za očekivati je da će $\bar{x}$ i $s$ biti raspodijeljene oko njihovih vrijednosti prema normalnim  raspodjelama
#
# za koje važi $\sigma_{\bar{x}}=s/\sqrt{N}$ (ovo je standardna greška srednje vrijednosti) i $\sigma_s=s/\sqrt{2(N-1)}\propto\sigma_{\bar{x}}$ (ovo je greška standardne devijacije). Primjećujemo da važi
#
#  $\sigma_{\bar{x}}\sim\sqrt{2}\sigma_s$
#
#
# $\blacksquare$ **P6**: Novčić se baca $16$ puta - to je jedna igra. Kako raste broj igara, broj dobijenih glava u jednoj igri prati normalnu raspodjelu sa srednjom vrijednošću
#  $\mu=8$
#
# i standardnom devijacijom $\sigma=2$. Standardna devijacija se ne može smanjiti jer je intrinzična *osobina* novčića. S druge strane, standardna greška srednje vrijednosti
#
# se smanjuje sa povećanjem $N$.

# %%
np.random.seed(2)
N = [5000, 15000]

plt.figure(figsize=(12, 5))
for i,j in enumerate(N):
    y = np.random.binomial(n=16, p=0.5, size=j)
    vrijednosti = []
    x = np.linspace(0, 16, num=16)
    for k in range(1,17):
        vrijednosti.append(np.count_nonzero(y == k))
    print(f'Srednja vrijednost = {np.mean(y):.2}, Standardna devijacija = {np.std(y):.2}')
    plt.subplot(1, 2, i+1)
    plt.bar(x, vrijednosti, color='grey', label=f'N={j}', alpha=0.5)
    plt.xlabel('Broj novčića')
    plt.ylabel('Broj uzoraka')
    plt.title(f'Binomna raspodjela, n=16, p=0.5, N={j}')
    plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Srednja vrijednost = 8.0, Standardna devijacija = 2.0
# Srednja vrijednost = 8.0, Standardna devijacija = 2.0

# %%
j = []
for i in [3, 30, 100, 1000]:
    uzorak = np.random.binomial(n=16, p=0.5, size= i)
    uzorak = round(sem(uzorak), 2) # SEM - standard error of the mean
    j.append(uzorak)

for i, val in zip([3, 30, 100, 1000], j):
    print(f'N = {i}: SEM = {val}')
# Out:
# N = 3: SEM = 1.15
# N = 30: SEM = 0.33
# N = 100: SEM = 0.18
# N = 1000: SEM = 0.06

# %% [markdown]
# *Estimatori* se mogu porediti u smislu efikasnosti - ovo se odnosi na to koliki je uzorak potreban da bi se dobila određena tačnost. Npr. medijana, dobijena iz podataka koji su
#
# *izvučeni* iz gausovske raspodjele, pokazuje raspršenje oko $\mu$ koje je $\pi/2$ veće od raspršenja srednje vrijednosti. Raspršenje se *smanjuje* kao $1/\sqrt{N}$, te je efikasnost srednje
#
# vrijednosti $\pi/2$ puta veća od efikasnosti medijane. Međutim, kad se radi se realnim podacima oni sadrže odstupajuće vrijednosti. Kvantili su robusnija metoda u određivanju
#
# parametara lokacije i skale nego što su to $\mu$ i $\sigma$. Medijana je robusnija u odnosu na srednju vrijednost, a tzv. interkvartilni opsjeg ($q_{75}-q_{25}$) je robusnija procjena skale nego
#
# što je to standardna devijacija. Interkvartilni opsjeg često služi u definiciji nepristrasnog *estimatora* za $\sigma$ od normalne raspodjele, tj. $\sigma_G=0.7413(q_{75}-q_{25})$. Što se tiče
#
#  izračuna standardne greške $\sigma_{qp}$ za kvantil $q_p$, koristi se formula:
#
# $$
# \sigma_{qp}=\frac{1}{h_p}\frac{\sqrt{p(1-p)}}{N},
# $$
#
# gdje je $h_p$ vrijednost raspodjele vjerovatnoće za $p$-ti percentil. Za Gausijan, standardna greška medijane je
#
# $$
# \sigma_{q50}=s\frac{\sqrt{\pi}}{2N},
# $$
#
# sa $h_{50}=1/(s\sqrt{2\pi})$ i $s\sim\sigma$ za veliko $N$.
#
#
# $\blacksquare$ **P7**: Dobar pokazatelj robusnosti medijane i $\sigma_G$ je uzorkovanje Gausijana sa i bez odstupajućih vrijednosti.

# %%
norm = np.random.normal(loc=8.0, scale=1.0, size=100) # 100 uzoraka iz normalne raspodjele 
a = np.random.normal(loc=8.0, scale=1.0, size=95) # 95 uzoraka iz normalne raspodjele
b = cauchy.rvs(loc=8.0, scale=20, size=5) # 5 uzoraka iz Košijeve raspodjele
odstupajuca_vrijednost = np.concatenate([a, b]) # kombinacija za stvaranje normalne raspodjele sa odstupajućim vrijednostima


srednje_vrijednosti = [np.mean(norm), np.mean(odstupajuca_vrijednost)]
standardne_devijacije = [np.std(norm), np.std(odstupajuca_vrijednost)]
medijane = [np.median(norm), np.median(odstupajuca_vrijednost)]

sigmaG = [0.7413 * (np.percentile(uzorak, 75) - np.percentile(uzorak, 25)) for uzorak in [norm, odstupajuca_vrijednost]]

# %%
labels = ['bez autlajera', 'sa autlajerima'] # autlajer = odstupajuća vr.
x = np.arange(len(labels))
width = 0.3

plt.figure(figsize=(12, 5))
plt.subplot(121)
bars1 = plt.bar(x - width/2, srednje_vrijednosti, width, label=r'$\mu$', color='grey', alpha=0.8)
bars2 = plt.bar(x + width/2, standardne_devijacije, width, label=r'$\sigma$', color='indianred', alpha=0.8)
plt.bar_label(bars1, padding=3, fmt='%.2f')
plt.bar_label(bars2, padding=3, fmt='%.2f')
plt.xticks(x, labels)
plt.ylabel('vrijednost')
plt.legend()

plt.subplot(122)
bars3 = plt.bar(x - width/2, medijane, width, label='medijana', color='grey', alpha=0.8)
bars4 = plt.bar(x + width/2, sigmaG, width, label=r'$\sigma_G$', color='indianred', alpha=0.8)
plt.bar_label(bars3, padding=3, fmt='%.2f')
plt.bar_label(bars4, padding=3, fmt='%.2f')
plt.xticks(x, labels)
plt.ylabel('vrijednost')
plt.legend()
plt.suptitle('Uticaj odstupajućih vrijednosti na robusnost deskriptivne statistike')
plt.tight_layout()
plt.show()
