# %% [markdown]
# ### $\color{indianred}{\text{ASTROSTATISTIKA - v5}} $
#
# <hr style="border: none; height: 2px; background-color: indianred; opacity: 0.5;" />

# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.stats import norm, poisson
from scipy import interpolate
import seaborn as sb
import matplotlib
from scipy.optimize import minimize
from scipy.stats import truncnorm
from scipy.stats import chi2
matplotlib.rcParams.update({"text.usetex": False, "font.size" : 10, "font.family": "monospace"})

# %% [markdown]
# Jedan od najpoznatijih metoda za određivanje ocjena parametra neke raspodjele jeste metod maksimalne vjerodostojnosti (*Maximum Likelihood Estimation* - **MLE**
#
# [koristićemo taj *termin*]). On nalazi primjenu u slučajevima od testiranja hipoteza, pa sve do mašinskog učenja. Polazna tačka za MLE i Bajesovsko zaključivanje je
#
# *vjerodostojnost* podataka. To je kvantitativni opis procesa mjerenja. Koncept je uveden od strane Gausa i Laplasa, a popularizovan od strane Fišera u XX vijeku. Ako
#
# pretpostavimo ili poznajemo ponašanje mjernog aparata (statistički - raspodjele odakle uzorkujemo), može se izračunati vjerovatnoća da se dobije bilo koja data
#
# vrijednost. Npr. ako se pretpostavi da je skup podataka $\{x_i\}$ izvučen iz $\mathcal{N}(\mu,\sigma)$, i da su individualne vrijednosti nezavisne, onda se *likelihood* čitavog skupa
#
# podataka može predstaviti kao proizvod vjerovatnoća za svaku pojedinačnu vrijednost:
#
# $$
# L\equiv p(\{x_i\}\,|\,M(\vec{\theta}))=\prod_{i=1}^Np(x_i\,|\,M(\vec{\theta})),
# $$
#
# gdje $M$ predstavlja model (pretpotavke o procesu mjerenja i sl.) koji uključuje $k$ parametara modela $\theta_p$, $p=1,\dots,k$ (često se koristi vektorski zapis $\vec{\theta}$ za koji se
#
# kaže da ima komponente $\theta_p$). Iako se $L\equiv p(\{x_i\}\,|\,M(\vec{\theta}))$ može tumačiti kao vjerovatnoća *za podatke* uz dati model, $L$ ipak nije PDF jer dati proizvod više nije
#
# normalizovan na 1. Takođe, pošto je čest slučaj da je vrijednost $L$ jako mala, onda se koristi $\ln{L}$. Drugim riječima, $L$ je samo združena vjerovatnoća da se dobije
#
# čitav skup podataka - za nezavisne događaje $A$ i $B$, združena vjerovatnoća je proizvod individualnih vjerovatnoća $p(A)p(B)$. Takođe, $L$ se može uzeti kao funkcija
#
# podataka ili funkcija modela. Kada se računa $L$ za neku vrijednost $x$, onda imamo funkciju za fiksne parametre modela. Ako se pak, koristi fiksni skup podataka, $L$
#
# se može smatrati za funkciju parametara modela. Ti parametri se variraju i vrši se *maksimizacija*.
#
# ---
#
# MLE procedura se sastoji iz nekoliko konceptualnih koraka:
#
# 1. Formiranje vjerovatnoće $p(D\,|\,M)$ za model $M$. Ovo je u suštini pretpostavka o tome kako su podaci generisani (u pitanju je jako važan korak);
#
# 2. Traže se najbolji parametri modela $\theta$ koji maksimizuju $p(D\,|\,M)$. Ovdje se dobijaju MLE procjene $\vec{\theta}^0$ (ili $\theta_p^0$, $p=1,\dots,k$ - tj. najbolje procjene parametara);
#
# 3. Određivanje intervala / opsjega povjerenja za $\vec{\theta}^0$. Ovo se može uraditi analitički (specifikacije zavise od modela), ili numerički (postje razne frekventističke
#
# tehnike poput *bootstrap*, *jackknife* ili metode *kros-validacije*);
#
# 4. Sprovođenje testiranja hipoteza. Nužno je doći do zaključaka vezano za modele i procjene $\vec{\theta}^0$.
#
# ---
#
# MLE se može primijeniti na *homoskedastičan* i *heteroskedastičan* Gausijan. To su jednostavni slučajevi.
#
# $\blacksquare$ **P1**: Astronom želi da izmjeri prividnu magnitudu zvijezde koja je na nekoj fiksnoj udaljenosti od Zemlje. Dobio je niz mjerenja. Cilj je naći MLE za prividnu magnitudu
#
#  i njen interval povjerenja.
#
# 1. Hipoteza: posmatrana zvijezda se ne kreće i njen sjaj ne fluktuira. Greške mjerenja prate $\mathcal{N}$, i svako mjerenje ima istu grešku (homoskedastičnost);
#
# 2. Izvodi se izraz za $L$ za to da postoji zvijezda određene magnitude koja daje dobijena mjerenja. Traži se vrijednost za koju su posmatranja najviše vjerovatna;
#
# 3. Procjenjuju se greške, tj. interval povjerenja mjerenja;
#
# 4. Testira se da li su podaci u saglasnosti sa modelom.

# %% [markdown]
# S obzirom da su greške gausovskog oblika, funkcija gustine vjerovatnoće za svako mjerenje data je preko:
#
# $$
# p(x\,|\,\mu, \sigma) = \frac{1}{\sqrt{2\pi}\,\sigma}e^{\frac{-(x_i - \mu)^2}{2\sigma^2}}.
# $$
#
# Združena vjerovatnoća za dobijanje čitavog skupa podataka, dobija se preko proizvoda individualnih vjerovatnoća (nezavisnost od ranije):
#
# $$
# L \equiv p(\{x_i\}\,|\,\mu, \sigma) = \prod_{i=1}^{N} \frac{1}{\sqrt{2\pi}\,\sigma}e^{\frac{-(x_i - \mu)^2}{2\sigma^2}}.
# $$
#
# Postoji samo jedan parametar modela, dakle $k=1$ i $\theta_p=\mu$ (svako mjerenje ima istu grešku). Sada se traži MLE procjena $\mu^0$, kao vrijednost $\mu$ koja maksimizuje $L$.
#
# Rekli smo da vrijednosti $L$ mogu da budu jako male, te je bolje koristiti $\ln{L}=\ln[L(\vec{\theta})]$, i to je tzv. *log-likelihood*. Maksimum za $\ln{L}$ je isti kao od $L$, i ovo važi ako
#
# je $L$ pomnoženo sa nekom konstantom. Vrijednost od $\mu$ koja maksimizuje $L$ se dobija iz:
#
# $$
# \left.\frac{d\ln L(\mu)}{d\mu}\right|_{\mu^0} \equiv 0.
# $$
#
# Može se iskoristiti sljedeća osobina:
#
#
# $$
# L = \left(\prod_{i=1}^{N} \frac{1}{\sigma\sqrt{2\pi}}\right) e^{-\frac{1}{2}\sum_{i=1}^{N}\left[\frac{x_i - \mu}{\sigma}\right]^2},
# $$
#
# te se dalje može pisati:
#
# $$
# \ln L(\mu) = \sum_{i=1}^{N} \ln\!\left(\frac{1}{\sigma\sqrt{2\pi}}\right) - \frac{1}{2\sigma^2}\sum_{i=1}^{N}(x_i - \mu)^2,
# $$
#
# $$
# \ln L(\mu) = -N\ln(\sigma\sqrt{2\pi}) - \frac{1}{2\sigma^2}\sum_{i=1}^{N}(x_i - \mu)^2.
# $$
#
# Pošto je $\sigma$ poznato i konstantno, samo drugi dio zavisi od $\mu$:
#
# $$
# \frac{d\ln L}{d\mu} = -\frac{1}{2\sigma^2}\sum_{i=1}^{N}\frac{d}{d\mu}(x_i - \mu)^2.
# $$
#
# Izračunamo:
#
# $$
# \frac{d}{d\mu}(x_i - \mu)^2 = 2(x_i - \mu)(-1) = -2(x_i - \mu),
# $$
#
# i onda dalje imamo:
#
# $$
# \frac{d\ln L}{d\mu} = -\frac{1}{2\sigma^2}\sum_{i=1}^{N}\left[-2(x_i - \mu)\right] = \frac{1}{\sigma^2}\sum_{i=1}^{N}(x_i - \mu).
# $$
#
# Iz uslova *zadatka* slijedi:
#
# $$
# \frac{1}{\sigma^2}\sum_{i=1}^{N}(x_i - \mu^0) = 0\iff\sum_{i=1}^{N} x_i - \sum_{i=1}^{N}\mu^0 = 0,
# $$
#
# odnosno:
#
# $$
# \sum_{i=1}^{N} x_i = N\mu^0\iff\mu^0 = \frac{1}{N}\sum_{i=1}^{N} x_i = \bar{x}.
# $$
#
# Dobijeno $\mu^0$ je aritmetička sredina svih mjerenja.
#
# Konkretnija formulacija primjera: postoji 120 mjerenja prividne magnitude, a ta mjerenja su izvučena iz $\mathcal{N}(8,2)$.

# %%
np.random.seed(seed=42)
Ns = 100
mu_pravo = 8
x = np.linspace(0, 16, 1000)
mjerenja = np.random.normal(mu_pravo, 2, Ns) 

prod = []
for i in x:
    j = np.prod(norm(mjerenja, 2).pdf(i))
    prod.append(j)

print(f"Srednja vrijednost: {np.mean(mjerenja):.2f}", f"Srednja vrijednost koja maksimizuje L: {x[np.argmax(prod)]:.2f}")
plt.figure(figsize=(12,5)) 
plt.subplot(121)
plt.hist(mjerenja, bins=20, density=True, histtype='step', color='grey')
plt.plot(x, norm(8, 2).pdf(x), color='indianred', label='pdf')
plt.xlabel(r'$x$')
plt.ylabel(r'N')
plt.xlim(0, 16)
plt.xticks(np.arange(0,16,2))
plt.legend()

plt.subplot(122)
plt.plot(x, prod, color='springgreen', label=r'$L(\mu)$')
plt.xlim(0, 16)
plt.xticks(np.arange(0,16, 2))
plt.xlabel(r'$\mu$')
plt.ylabel(r'$L(\mu)$');
plt.legend()
plt.suptitle(r'Primjer homoskedastičnog Gausijana u MLE kontekstu')
plt.tight_layout()
plt.show()
# Out:
# Srednja vrijednost: 7.79 Srednja vrijednost koja maksimizuje L: 7.80

# %% [markdown]
# <hr style="border: none; height: 2px; background-color: magenta; opacity: 0.5;" />
#
# $\color{magenta}{\text{Z1}}$ : Maksimizovati funkciju vjerodostojnosti za Poasonovu raspodjelu.
#
# <hr style="border: none; height: 2px; background-color: magenta; opacity: 0.5;" />
#
# $\color{magenta}{\text{R1}}$ :
#
#
# Važi:
# $$
# p(x_i\,|\,\mu) = \frac{e^{-\mu} \mu^{x_i}}{x_i!},
# $$
#
# gdje je $\mu$ prosječan broj događaja, $N$ broj posmatranih događaja, a $\{x_i\}$ *izmjereni* podaci. $L$ se piše kao:
#
# $$
# L \equiv p(\{x_i\} | \mu) = \prod_{i=1}^{N} \frac{e^{-\mu} \mu^{x_i}}{x_i!},
# $$
#
# odakle se može dobiti i $\ln{L}$:
#
# $$
# \ln L = \sum_{i=1}^{N} \ln\left( \frac{e^{-\mu} \mu^{x_i}}{x_i!} \right)= \sum_{i=1}^{N} \left( -\mu + x_i \ln(\mu) - \ln(x_i!) \right)
# $$
#
# Za Poasonovu raspodjelu, MLE procedura se može odraditi i analitički:
#
# $$
# \frac{\partial\ln{L}(\mu)}{\partial \mu} = \frac{\partial}{\partial \mu} \left( \sum_{i=1}^{N} \Big( -\mu + x_i \ln(\mu)- \ln(x_i!\Big) \right),
# $$
#
# $$
# 0 = \sum_{i=1}^{N} \left( -1 + \frac{x_i}{\mu} \right) \implies\hat{\mu} = \frac{1}{N} \sum_{i=1}^{N} x_i.
# $$

# %%
mu_izbor = np.linspace(3,20,100) 
p_podaci = poisson.rvs(12, size=100)

lnL_tekuce = []
for mu in mu_izbor: 
    lnL_priv = poisson.logpmf(p_podaci, mu=mu) 
    lnL_priv = np.sum(lnL_priv) 
    lnL_tekuce.append( lnL_priv )
lnL_tekuce = np.array(lnL_tekuce)
plt.plot(mu_izbor,lnL_tekuce, color='grey')
findmax = mu_izbor[np.argmax(lnL_tekuce)]
print('Najvjerovatnija vrijednost za mu:', np.round(findmax,4))
plt.axvline(findmax, color='indianred')
plt.axvline(12, color='springgreen',ls='dotted')
plt.title('MLE za Poasonovu raspodjelu')
plt.xlabel(r'$\mu$')
plt.ylabel(r'$\ln{L}$')
plt.show()
# Out:
# Najvjerovatnija vrijednost za mu: 12.2727

# %% [markdown]
# <hr style="border: none; height: 2px; background-color: magenta; opacity: 0.5;" />
#
# $\color{magenta}{\text{Z2}}$ : Maksimizovati funkciju vjerodostojnosti za Košijevu raspodjelu, koristeći se Njutnovom metodom.
#
# <hr style="border: none; height: 2px; background-color: magenta; opacity: 0.5;" />
#
# $\color{magenta}{\text{R2}}$ :
#
#
# $$
# f(x, \theta) = \frac{1}{\pi}\frac{1}{1+(x-\theta)^2}
# $$
#
# $$
# l(\theta) = -\sum_{i=1}^{n}\log(1+(x_i-\theta)^2) - n\log\pi
# $$
#
# $$
# \frac{d}{d\theta}l(\theta) = \sum_{i=1}^{n}\frac{2(x_i-\theta)}{1+(x_i-\theta)^2}
# $$
#
# $$
# \frac{d^2}{d\theta^2}l(\theta) = -2\sum_{i=1}^{n}\frac{1-(x_i-\theta)^2}{(1+(x_i-\theta)^2)^2}
# $$
#
# $$
# \theta_{n+1} = \theta_n - \frac{\dfrac{d}{d\theta}l(\theta_n)}{\dfrac{d^2}{d\theta^2}l(\theta_n)}
# $$

# %%
np.random.seed(21321)
xs = np.random.standard_cauchy(1000) + 10

def log_likelihood(theta, x):
    return -np.sum(np.log(1 + (x - theta)**2)) - len(x) * np.log(np.pi)

def dlogL(theta, x):
    return np.sum(2 * (x - theta) / (1 + (x - theta)**2))

def d2logL(theta, x):
    return -2 * np.sum((1 - (x - theta)**2) / (1 + (x - theta)**2)**2)

def njutn(theta0, x, tol=1e-6, maxiter=100):
    theta = theta0
    for _ in range(maxiter):
        step = dlogL(theta, x) / d2logL(theta, x)
        theta -= step
        if np.abs(step) < tol:
            break
    return theta

theta_hat = njutn(theta0=np.median(xs), x=xs)
print(f'MLE procjena: {theta_hat:.4f}')

theta_grid = np.linspace(0, 20, 1000)
plt.plot(theta_grid, [dlogL(t, xs) for t in theta_grid])
plt.axhline(0, color='grey', ls='dotted')
plt.axvline(theta_hat, color='indianred', label=rf'$\hat{{\theta}} = {theta_hat:.3f}$')
plt.axvline(10, color='springgreen', ls='dotted', label=r'$\theta_{\rm pravo} = 10$')
plt.xlabel(r'$\theta$')
plt.ylabel(r'$\frac{d}{d\theta}l(\theta)$')
plt.title(r'Njutnova metoda za MLE Košijeve raspodjele')
plt.legend()
plt.show()
# Out:
# MLE procjena: 9.9807

# %% [markdown]
# Može se navesti više osobina MLE *estimatora*, koje su vezane za optimalnost, a izvedene su pod određenim pretpostavkama. Najvažnija pretpostavka je svakako to
#
# da su podaci zaista potekli iz specifikovanog modela (npr. stvarno su izvučeni iz Gausijana ako je taj model korišćen). MLE *estimatori* su konzistentni i asimptotski
#
# normalni. U graničnom slučaju postižu teorijski minimalnu moguću varijansu - tzv. Kramer-Rao granica.

# %% [markdown]
# Neodređenost MLE se nalazi traženjem drugog izvoda od $\ln{L}$ u odnosu na parametre:
#
# $$
# F_{jk} = -\frac{d^2 \ln L}{d\theta_j\, d\theta_k}\Bigg|_{\theta=\theta_0}.
# $$
#
# Izraz iznad je povezan sa tzv. očekivanom Fišerovom informacijom, koja je definisana kao očekivana vrijednost drugog izvoda od $\ln{L}$ u odnosu na $\theta$. Inverz Fišerove
#
# informacione matrice daje donju granicu za varijansu za bilo koju nepristrasnu procjenu $\theta$ - to je baš Kramer-Rao granica. Neodređenosti formiraju matricu kovarijanse:
#
# $$
# \Sigma_{jk} = [F^{-1}]_{jk},
# $$
#
# gdje je $\sigma_j = \sqrt{\Sigma_{jj}}$.
#
# U slučaju homoskedastičnih greški iz normalne raspodjele, neodređenost srednje vrijednosti je:
#
# $$
# \sigma_\mu = \left(-\frac{d^2 \ln L(\mu)}{d\mu^2}\Bigg|_{\mu^0}\right)^{-1/2} = \left(\sum_{i=1}^{N}\frac{1}{\sigma_i^2}\right)^{-1/2} = \frac{\sigma}{\sqrt{N}}
# $$

# %% [markdown]
# Vjerovatnoća uzorkovanja $x$ se karakteriše vjerovatnoćom izbora ili funkcijom izbora $S(x)$. Ako je npr. $S(x)=0$ za $x>x_{\rm max}$ (analogno za $x<x_{\rm min})$ onda nemamo
#
# nikakvu informaciju o izvorima podataka za koje $x>x_{\rm max}$, čak ni to da li postoje ili ne postoje. Povezan koncept su tzv. cenzurisani skupovi podataka, gdje je mjerenje
#
# postojećeg izvora pokušano, ali je dobijena vrijednost van nekog poznatog intervala (npr. gornji limit što se tiče mjerenja fluksa u astronomiji). Vraćanjem na Gausijan od
#
# ranije, može se pokazati kako se uzima u obzir ovo *otkidanje* podataka, kad se koristi MLE. Radi jednostavnosti, $S(x)=1$ za $x_{\rm min}<x<x_{\rm max}$ i $S(x)=0$ inače.
#
# $L$ *jednog podatka* mora biti pravilno normalizovana funkcija gustine vjerovatnoće. Ovo se uračunava preko neke konstante renormalizacije. U slučaju gausovske raspodjele
#
# greške imamo:
#
# $$
# p(x_i|\mu, \sigma, x_{\min}, x_{\max}) = C(\mu, \sigma, x_{\min}, x_{\max})\frac{1}{\sqrt{2\pi}\,\sigma}e^{\frac{-(x_i-\mu)^2}{2\sigma^2}},
# $$
#
# gdje se konstanta renormalizacije računa preko:
#
# $$
# C(\mu, \sigma, x_{\min}, x_{\max}) = \left(P(x_{\max}|\mu,\sigma) - P(x_{\min}|\mu,\sigma)\right)^{-1}.
# $$
#
# Ovdje figuriše $P$, odnosno kumulativna funkcija raspodjele za Gausijan centriran na $\mu$, sa standardnom devijacijom $\sigma$. Dalje, pišemo:
#
#
# $$
# \ln L(\mu) = \text{const.} - \sum_{i=1}^{N}\frac{(x_i-\mu)^2}{2\sigma^2} + N\ln[C(\mu, \sigma, x_{\min}, x_{\max})]
# $$

# %% [markdown]
# $\blacksquare$ **P2**: Površinu planete Kaladan, koja orbitira oko zvijezde $\delta$ Pavonis, često udaraju meteoriti. Pretpostavka je da postoji muzej velikih meteorita, koji su stanovnici
#
# te planete namijenili za meteorite veće od $45\,\rm m$ u prečniku. Poznato je da na Kaladanu meteoriti *prate* normalnu raspodjelu centriranu na $25\,\rm m$ sa $\sigma=13\,\rm m$.
#
# U muzeju, prije izlaganja, meteoriti stoje u posebnoj prostoriji za ispitivanje i mjerenje. Kustos tamo nailazi na meteorit prečnika $S_d$. Koja je najbolja procjena srednje
#
# vrijednosti prečnika meteorita ako je kustosu poznata standardna devijacija od $13\,\rm m$, ali ne i navedena srednja vrijednost?
#
# Odgovor na ovo pitanje se dobija traženjem maksimuma $\ln{L}$, evaluiranog za $x_{\rm min}=45$, $x_{\rm max}=\infty$, $N=1$, $x_1=S_d$ i $\sigma=13$. To da li je $\mu^0$ (koje maksimizuje $L$)
#
# veće ili manje od $25$ zavisi od vrijednosti $S_d$.

# %%
plt.figure(figsize=(12,5) )

x = np.linspace(44, 75, 1000)
sv = 25
std = 13
x_min = 45
x_max = np.inf
a, b = (x_min - sv) / std, (x_max - sv) / std
r = truncnorm.rvs(a, b, loc = sv, scale = std, size=1000)
print(f'Srednja vrijednost: {np.mean(r):.3}')
plt.plot(x, truncnorm.pdf(x,a,b,loc = sv, scale = std), color = 'indianred', label = 'pdf')
plt.hist(r, bins = 30, density = True, histtype = 'step', color = 'grey')
plt.xlabel(r'$x$')
plt.ylabel(r'$N$')
plt.title('Tzv. skraćeni Gausijan')
plt.show()
# Out:
# Srednja vrijednost: 50.6

# %% [markdown]
# Sljedeći korak bi bio da se maksimizuje $\ln{L}$. To je teško analitički izvesti, jer bi onda bilo potrebno naći parcijalni izvod kumulativne funkcije raspodjele (koja sadrži `erf`)
#
# u odnosu na $\mu$. Ovo se može izbjeći korišćenjem `scipy.optimize.minimize` na negativnoj funkciji $\ln{L}$.

# %%
const = (-1/2)*(np.log(2*np.pi*(13**2)))

def neg_log_likelihood(mu, x_1, x_2=0, n=1, sum_term_x2 = 0):
    sum_term_x1 = ((x_1 - mu)**2)/(2*(13**2))
    
    if x_2 != 0:
        sum_term_x2 = ((x_2 - mu)**2)/(2*(13**2))
    
    norm_constant = np.log((norm(mu,13).cdf(x_max) - (norm(mu,13).cdf(x_min)))**(-1))
    logL = -(const - (sum_term_x1+sum_term_x2)+(n*norm_constant))
    return logL

# %%
print(f"""Vrijednost mu koja maksimizuje lnL za: \n\n

S_d = 49: {minimize(neg_log_likelihood, 15,args = (49)).get("x")[0]:.4}
S_d = 52: {minimize(neg_log_likelihood, 30,args = (52)).get("x")[0]:.4}

Vrijednosti mu koje maksimizuju lnL za: \n\n

S_d1 = 49, S_d2 = 50 (oba meteorita sa prečnicima ispod srednje vrijednosti): {minimize(neg_log_likelihood,15, args = (49,50,2)).get("x")[0]:.4}
S_d1 = 50, S_d2 = 51 (jedan iznad srednje, jedan ispod srednje): {minimize(neg_log_likelihood,25, args = (50,51,2)).get("x")[0]:.4}
S_d1 = 52, S_d2 = 53 (oba meteorita sa prečnicima iznad srednje vrijednosti): {minimize(neg_log_likelihood, 30, args = (52,53,2)).get("x")[0]:.4}""")
# Out:
# Vrijednost mu koja maksimizuje lnL za:
#
#
#
# S_d = 49: 10.21
# S_d = 52: 32.85
#
# Vrijednosti mu koje maksimizuju lnL za:
#
#
#
# S_d1 = 49, S_d2 = 50 (oba meteorita sa prečnicima ispod srednje vrijednosti): 15.72
# S_d1 = 50, S_d2 = 51 (jedan iznad srednje, jedan ispod srednje): 24.1
# S_d1 = 52, S_d2 = 53 (oba meteorita sa prečnicima iznad srednje vrijednosti): 35.15

# %% [markdown]
# ---
#
# Služeći se MLE procedurom, mi sada možemo da procijenimo parametre modela *najboljeg fita*, i njihove neodređenosti. Međutim, to ne govori ništa o tome koliko
#
# je fit zapravo *dobar*. Npr. ako pretpostavimo gausovski model, a u realnosti podaci ne prate $\mathcal{N}$ onda rezultati neće biti korisni. Maksimalnu vrijednost $L$ možemo
#
# označiti sa $L^0$. Pretpostavljajući da je naš model tačan, može se postaviti pitanje vezano za to koliko je vjerovatno da se dobijena vrijednost *pojavila* slučajno.
#
# Ako je malo vjerovatno da se dobije $L^0$ (ili $\ln{L_0}$), slučajnim izvlačenjem podataka iz raspodjele *najboljeg fita*, onda model ne daje dobar opis za podatke. Ako
#
# se prisjetimo slučaja sa Gausijanom, imali smo jednakost:
#
# $$
# \ln L(\mu) = \text{const.} - \sum_{i=1}^{N}\frac{(x_i - \mu)^2}{2\sigma^2},
# $$
#
# koja se može napisati i kao:
#
# $$
# \ln L = \text{const.} - \frac{1}{2}\chi^2,\quad\chi^2 = \sum_{i=1}^{N}\left(\frac{x_i - \mu}{\sigma}\right)^2.
# $$
#
# Dakle, raspodjela $\ln{L}$ može biti određena iz $\chi^2$ raspodjele sa $N-k$ stepeni slobode, gdje je $k$ broj parametara modela određenih iz podataka.
# Za dobar fit treba da važi:
#
# $$
# \chi^2_{\rm dof} = \frac{1}{N-k}\sum_{i=1}^{N}\left(\frac{x_i - \mu}{\sigma}\right)^2 \approx 1
# $$

# %%
np.random.seed(seed=42)
Ns = 10
mu = 25
sigma = 13

x = np.random.normal(mu, sigma, Ns) # tačan model
mu = np.average(x)
chi_2 = np.sum(np.square((x - mu) / sigma))

x_poason = np.random.poisson(mu, Ns) # netačan model
mu_poason = np.average(x_poason)
chi_2_poason = np.sum(np.square((x_poason - mu_poason) / sigma))


plt.figure(figsize=(12,5))
z = np.linspace(0,32,1000)

plt.plot(z, chi2.pdf(z, Ns - 1), color='grey') # chi2 ima Ns-1 stepeni slobode jer smo procijenili mu iz podataka
plt.axvline(chi_2, color='indianred',label = f"Tačan model: {chi_2:.3}");
plt.axvline(chi_2_poason, color='springgreen',label = f"Netačan model: {chi_2_poason:.3}");

plt.ylim(0,0.12)
plt.legend(loc = "upper right", fontsize = 12)
plt.show()

# %% [markdown]
# Imamo jednostavana slučaj gdje je luminoznost zvijezde izmjerena više puta. Pretpostavka je da zvijezda nema intrinzičnu varijaciju luminoznosti. Razmatramo
#
# četiri slučaja - tačan model sa tačnim greškama, tačan model sa precijenjenim i potcijenjenim greškama i netačan model sa tačnim greškama. Zanima nas kako
#
# se $\chi^2_{\rm dof}$ ponaša kao dijagnostički alat u ovim različitim slučajevima.

# %%
np.random.seed(42)
N = 50
lum = 10
sigma_L = 0.2

t = np.linspace(0, 1, N)
L_obs = np.random.normal(lum, sigma_L, N)

y_vals = [L_obs, L_obs, L_obs, L_obs + 0.5 - t ** 2]
y_errs = [sigma_L, sigma_L * 2, sigma_L / 2, sigma_L]
titles = ['Tačan model, tačne greške',
          'Tačan model, precijenjene greške',
          'Tačan model, potcijenjene greške',
          'Netačan model, tačne greške']

fig = plt.figure(figsize=(14, 14))
fig.subplots_adjust(left=0.1, right=0.95, wspace=0.05, bottom=0.1, top=0.95, hspace=0.05)

for i in range(4):
    ax = fig.add_subplot(2, 2, 1 + i, xticks=[])

    mu = np.mean(y_vals[i])
    z = (y_vals[i] - mu) / y_errs[i]
    chi2 = np.sum(z ** 2)
    chi2dof = chi2 / (N - 1)

    sigma = np.sqrt(2. / (N - 1))
    nsig = (chi2dof - 1) / sigma

    ax.errorbar(t, y_vals[i], y_errs[i],fmt='.k', ecolor='gray', lw=1,ms = 12)
    ax.plot([-0.1, 1.3], [lum, lum], ':k', lw=3)

    ax.text(0.95, 0.95, titles[i], ha='right', va='top',
            transform=ax.transAxes,fontsize = 15,
            bbox=dict(boxstyle='round', fc='w', ec='k'))
    ax.text(0.02, 0.02, r'$\hat{\mu} = %.2f$' % mu, ha='left', va='bottom',
            transform=ax.transAxes, fontsize = 15)
    ax.text(0.98, 0.02, r'$\chi^2_{\rm dof} = %.2f\, (%.2g\,\sigma)$'
            % (chi2dof, nsig), ha='right', va='bottom', 
            transform=ax.transAxes,fontsize = 15)
    
    ax.set_xlim(-0.05, 1.05)
    ax.set_ylim(8.6, 11.4)

    ax.yaxis.set_major_locator(plt.MultipleLocator(1))
    if i > 1: ax.set_xlabel('posmatranja')
    if i % 2 == 0: ax.set_ylabel('Luminoznost')
    else: ax.yaxis.set_major_formatter(plt.NullFormatter())

plt.show()
