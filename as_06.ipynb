# %% [markdown]
# ### $\color{indianred}{\text{ASTROSTATISTIKA - v6}} $
#
# <hr style="border: none; height: 2px; background-color: indianred; opacity: 0.5;" />

# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.stats import norm, poisson
from scipy import interpolate
import seaborn as sb
import matplotlib
from scipy.optimize import minimize
from astropy.stats import jackknife_stats, jackknife_resampling
from scipy.stats import bootstrap, iqr
from time import time
from sklearn.mixture import GaussianMixture
matplotlib.rcParams.update({"text.usetex": False, "font.size" : 10, "font.family": "monospace"})

# %% [markdown]
# <hr style="border: none; height: 2px; background-color: magenta; opacity: 0.5;" />
#
# $\color{magenta}{\text{Z1}}$ :
#
# Mjerite poziciju zvijezde $N=10$ puta istim teleskopom (homoskedastične greške). Pretpostavimo da je pozadinski proces normalni, tj. $\mu_0 = 3$ (u odgovarajućim jedinicama), a greške su $\sigma = 1$.
#
#
# - Generišite $N$ izmjerenih pozicija. Svako mjerenje $x_i$ tretirajte kao procjenu tačne raspodjele - centrirajte Gausovu funkciju (sa poznatim $\sigma$) u svakoj tački. To je vjerovatnoća svake tačke podataka $p(x_i | \mu)$.
#
# - Nacrtajte svaku individualnu likelihood funkciju posebno. Nacrtajte i njihov proizvod - likelihood cijelog skupa podataka $\mathcal{L}(\mu) = \prod_i p(x_i|\mu)$.
#
# - Očitajte maksimum likelihood rješenje (npr. koristeći `np.argsort`).
#
# - Uporedite ga sa MLE estimatorom $\hat{\mu} = \bar{x}$.
#
# <hr style="border: none; height: 2px; background-color: magenta; opacity: 0.5;" />
#
# $\color{magenta}{\text{R1}}$ :

# %%
N = 10
mu = 3
sigma = 1 
np.random.seed(42) 
sample = norm(mu,sigma).rvs(N)
print(sample)
# Out:
# [3.49671415 2.8617357  3.64768854 4.52302986 2.76584663 2.76586304
#  4.57921282 3.76743473 2.53052561 3.54256004]

# %%
xgrid = np.linspace(0,7,1000)

Ls = np.array([norm.pdf(xgrid,loc=s,scale=sigma) for s in sample])
L = np.prod(Ls,axis=0)
    
for L in Ls:
    plt.plot(xgrid, L, ls=':')
    
plt.plot(xgrid, L, ls='-', c='black', label=r'$L(\{x\})$', lw=3)
plt.xlabel('$\mu$')
plt.ylabel(r'$p(x_i|\mu,\sigma)$')
plt.title('MLE procjena');

# %%
sortirani_indeksi = np.argsort(L)
index_max = sortirani_indeksi[-1]
print("L maks na %.3f" % xgrid[index_max])

MLest = np.mean(sample)
print("MLE:", MLest)
# Out:
# L maks na 3.546
# MLE: 3.448061111698756

# %% [markdown]
# ---
#
# Za mješavinu normalnih raspodjela $M$ može se pisati vjerovatnoća za jedan *podatak*:
#
# $$
# p(x_i|\vec{\theta}) = \sum_{j=1}^{M} \alpha_j \mathcal{N}(\mu_j, \sigma_j).
# $$
#
# Podaci $x=\{x_1,x_2,\dots,x_N\}$ su nezavisni i identično raspodijeljeni. Vektor parametara $\theta$ sadrži oteženjenosti $\alpha$ koje zadovoljavaju:
# $$
# \sum_{j=1}^{M} \alpha_j = 1.
# $$
#
# Iz jednačine za $p(x_i|\vec{\theta})$ slijedi:
#
# $$
# \ln L = \sum_{i=1}^{N} \ln \left[\sum_{j=1}^{M} \alpha_j \mathcal{N}(\mu_j, \sigma_j)\right].
# $$
#
# Ako radimo maksimizaciju, tražimo prvi izvod po svakom parametru:
#
# $$\frac{\partial \ln L}{\partial \mu_j} = \frac{\partial \ln L}{\partial \sigma_j} = \frac{\partial \ln L}{\partial \alpha_j} = 0,$$
#
# što će rezultovati sa $3M-1$ spregnutih nelinearnih jednačina. Ovo je sada jako kompleksan problem koji se srećom može pojednostaviti.
#
# Trik je u tome da se sistem ne rješava direktno, već se uvode tzv. *skrivene varijable*. Svaka tačka $x_i$ je generisana tačno jednom od $M$ Gausovih komponenti,
#
# ali ne znamo kojom. Indeks $j$ koji je generisao $x_i$ je skrivena varijabla. Umjesto da tražimo tačan $j$, svakom $x_i$ pripisujemo vjerovatnoću $p(j\,|\,x_i)$ pripadanja
#
# komponenti $j$, tzv. *odgovornost* (eng. *responsibility*). Računamo je Bayesovim pravilom, uz $p(j) = \alpha_j$:
#
# $$
# p(j|x_i) = \frac{p(x_i|j)\,p(j)}{\sum_{j=1}^{M} p(x_i|j)\,p(j)} = \frac{\alpha_j \mathcal{N}(\mu_j, \sigma_j)}{\sum_{j=1}^{M} \alpha_j \mathcal{N}(\mu_j, \sigma_j)}.
# $$
#
# Vrijedi $\sum_{j=1}^{M} p(j|x_i) = 1$. Ovo je osnova EM algoritma: iterativno se izmjenjuju korak dodjele odgovornosti i korak ažuriranja parametara $\mu_j,\,\sigma_j,\,\alpha_j$.

# %% [markdown]
# ---
#
# Popularan klasičan način upoređivanja modela je tzv. *Akaike information criterion*, dat kao:
# $$
# \text{AIC} \equiv -2\ln L^0(M) + 2k + \frac{2k(k+1)}{N-k-1},
# $$
#
# gdje je $L^0(M)$ maksimalna vrijednost funkcije vjerodostojnosti za model sa $M$ komponenti, $k$ je broj slobodnih parametara, a $N$ broj podataka. Prvi
#
# član nagrađuje model koji dobro fituje podatke, dok drugi i treći član kažnjavaju kompleksnost modela - modeli sa više parametara dobijaju veći AIC.
#
# Optimalan broj komponenti $M$ biramo kao onaj koji minimizuje AIC.

# %%
np.random.seed(42)

X = np.concatenate([
    np.random.normal(loc=2.0, scale=0.4, size=200),   
    np.random.normal(loc=5.0, scale=1.0, size=500),   
    np.random.normal(loc=8.5, scale=0.6, size=300),   
]).reshape(-1, 1)

N = np.arange(1, 11)
models = [GaussianMixture(n, random_state=42).fit(X) for n in N]

AIC = [m.aic(X) for m in models]
x = np.linspace(-1, 12, 1000)
M_best = models[np.argmin(AIC)]

logprob = M_best.score_samples(x.reshape(-1, 1))
resp  = M_best.predict_proba(x.reshape(-1, 1))
pdf = np.exp(logprob)
pdf_i= resp * pdf[:, np.newaxis]

plt.figure(figsize=(12, 5))
plt.hist(X, bins=80, density=True, histtype='step', color='royalblue', label='Podaci')
plt.plot(x, pdf, color='indianred', lw=3, label='Najbolji GMM')
for i in range(pdf_i.shape[1]):
    plt.plot(x, pdf_i[:, i], ls=':', label=f'Komponenta {i+1}')

plt.xlabel(r'$x$')
plt.ylabel(r'$p(x)$')
plt.legend()
plt.show()

# %% [markdown]
# Izrazi za računanje intervala povjerenja za procijenjene parametre su bazirani na jakim pretpostavkama (*normalnost* podataka, velike količine podataka itd.), te je
#
# poželjno naći neke alternative. Postoje dvije metode koje su veoma moćne, a zasnivaju se na reuzorkovanju skupa $\{x_i\}$.

# %% [markdown]
# ---
# Skup podataka $\{x_i\}$ se uzorkuje iz neke funkcije raspodjele $h(x)$. Međutim, ta funkcija raspodjele nije poznata, već se radi sa njenom procjenom $f(x)$. **Bootstrap**
#
# metoda je bazirana na sljedećoj aproksimaciji:
#
# $$
# f(x)=\frac{1}{N}\sum_{i=1}^N\delta(x-x_i),
# $$
#
# gdje je $\delta(x)$ Dirakova $\delta$-funkcija. Funkcija $f(x)$ maksimizuje vjerovatnoću dobijaja *posmatranih* podataka (ona je MLE procjena za $h$), te važi $f(x)\sim h(x)$. Kada se
#
# nalaze neodređenosti, prethodna jednačina se koristi da se izvuče arbitraran broj novih skupova podataka. Ima $N!$ mogučih *različitih* skupova uzoraka veličine $N$ i
#
# vjerovatnoća da je novi skup podataka identičan originalnom jeste $N!/N^n$ (za $N=10$, ova vjerovatnoća je $3.6\cdot10^{-4}$). Dakle, iz posmatranog skupa podataka se
#
# izvlači sa zamjenom: bira se $N$ novih vrijednosti indeksa $j$ od $i=1,\dots, N$. Neke vrijednosti iz $\{x_i\}$ se mogu pojaviti dva ili više puta tokom reuzorkovanja. Čitava
#
# procedura se radi $B$ puta, a rezulutujućih $B$ skupova podataka služi da se izračuna statistika od interesa, i to $B$ puta. Raspodjela dobijenih vrijednosti će *mapirati*
#
# neodređenost statistike, te se mogu procijeniti *bias*, standardna greška i sl. Ovo je opis za neparametarski bootstrap (parametarski je povezan sa najboljim fitom).
#
# $\blacksquare$ **P1**: Bootstrap metodom naći procjene neodređenosti standardne devijacije $\sigma$ i $\sigma_G$ od uzorka koji ima $m=1000$ vrijednosti, a *dobijen* je iz normalne raspodjele
#
# $\mathcal{N}(\mu=0,\sigma=1)$. Reuzorkovanje se radi $N=10^4$ puta. Prema teoriji, neodređenosti za $\sigma$ i $\sigma_G$ se nalaze prema jednačinama ($s$ je standardna devijacija uzorka):
# $$
# \sigma_s = \frac{s}{\sqrt{2(m-1)}},
# $$
#
# $$
# \sigma_{\sigma_G} = \frac{1.06\, s}{\sqrt{m}}.
# $$

# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.stats import norm, poisson
from scipy import interpolate
import seaborn as sb
import matplotlib
from scipy.optimize import minimize
from astropy.stats import jackknife_stats, jackknife_resampling
from scipy.stats import bootstrap, iqr

m = 100
n = 1000

np.random.seed(42)
podaci = norm(3, 1).rvs(m)

rez1 = bootstrap((podaci,), lambda x: np.std(x, ddof=1), n_resamples=n)
sigmaG = lambda x: 0.7413 * iqr(x) 
# rez2 = bootstrap((podaci,), sigmaG, n_resamples=n)

mu1_bootstrap = rez1.bootstrap_distribution
# mu2_bootstrap = rez2.bootstrap_distribution

s = podaci.std(ddof=1)
xgrid = np.linspace(0, 1.5, 1000)
sigma1 = s / np.sqrt(2 * (m - 1))
pdf1 = norm(s, sigma1).pdf(xgrid)

# sigma2 = 1.06 * s / np.sqrt(m)
# pdf2 = norm(s, sigma2).pdf(xgrid)

plt.figure(figsize=(12, 5))
plt.hist(mu1_bootstrap, bins=50, density=True, histtype='step', lw=1, color='royalblue', ls='-.', label=r'$\sigma$')
plt.plot(xgrid, pdf1, color='grey', lw=2, label=r'$\sigma_s=s/\sqrt{2(N-1)}$')
# plt.hist(mu2_bootstrap, bins=50, density=True, histtype='step', lw=1, color='indianred', ls='-.',label=r'$\sigma_G=0.7413\,{\rm IQR}$')
# plt.plot(xgrid, pdf2, color='springgreen', lw=2, label=r'$\sigma_{\sigma_G}=1.06\,s/\sqrt{N}$')


plt.xlabel(r'$\sigma$')
plt.ylabel(r'$p(\sigma\,|\,x,I)$')
plt.legend()
plt.title(r'Bootstrap: neodređenost u standardnoj devijaciji')
plt.show()

# %% [markdown]
# ---
#
# **Jackknife** metoda je slična bootstrap metodi, ali umjesto reuzorkovanja sa skupom podataka koji je identične veličine kao originalni, jedna ili više observabli ostaju
#
# neiskorišćene tokom izračuna statistike od interesa. Ova statistika se naziva $\alpha$, a njena vrijednost dobijenja iz cijelog (punog) skupa podataka je $\alpha_N$. Pretpostavlja se
#
# da se jedna opservabla uklanja tokom reuzorkovanja, te se formira $N$ skupova podataka i računa se statistika $\alpha_i^*$ za svaki od njih. Za taj slučaj, procjena od $\alpha$ data je
#
# sljedećom jednačinom:
#
# $$
# \alpha^J=\alpha_N+\Delta\alpha,
# $$
#
# gdje je Jackknife korekcija:
#
# $$
# \Delta\alpha = (N-1)\left(\alpha_N - \frac{1}{N}\sum_{i=1}^{N}\alpha_i^*\right).
# $$
#
#
# Za *estimatore* koji su asimptotski normalni, standardna greška procjene jeste:
#
# $$
# \sigma_\alpha = \sqrt{\frac{1}{N(N-1)}\sum_{i=1}^{N}\left[N\alpha_N - \alpha^J - (N-1)\alpha_i^*\right]^2}.
# $$
#
# $\blacksquare$ **P2**: Jackknife metodom naći procjene neodređenosti standardne devijacije $\sigma$ i $\sigma_G$ od uzorka koji ima $m=1000$ vrijednosti, a *dobijen* je iz normalne raspodjele
#
# $\mathcal{N}(\mu=0,\sigma=1)$. Dobiće se da rezultat za $\sigma$ ima poklapanje se sa teorijom, ali jackknife ne *funkcioniše* za $\sigma_G$ (i druge rang-bazirane statistike)!

# %%
m = 1000

np.random.seed(123)
podaci = norm(0, 1).rvs(m)

reuzorci = jackknife_resampling(podaci)  # (m, m-1)

mu1_r = np.std(reuzorci, axis=1, ddof=1)
mu1, _, sigma_mu1, _ = jackknife_stats(podaci, lambda x: np.std(x, ddof=1))
pdf1 = norm(1, 1. / np.sqrt(2 * (m - 1)))
pdf1_jackknife = norm(mu1, sigma_mu1)
print(f"mu_s = {mu1:.4}, sigma_mu_s = {sigma_mu1:.4}")


mu2_r = np.array([sigmaG(row) for row in reuzorci])
mu2, _, sigma_mu2, _ = jackknife_stats(podaci, sigmaG)
pdf2= norm(podaci.std(), 1.06 / np.sqrt(m))
pdf2_jackknife = norm(mu2, sigma_mu2)
print(f"mu_sigmaG = {mu2:.4}, sigma_mu_sigmaG = {sigma_mu2:.4}")

fig = plt.figure(figsize=(12, 5))
plt.subplot(121)
plt.hist(mu1_r, np.linspace(0.996, 1.008, 100), label=r'$\sigma^*$', histtype='step', color='grey', density=False)
plt.hist(mu2_r, np.linspace(0.996, 1.008, 100), label=r'$\sigma_G^*$ (kvartil)', histtype='step', color='indianred', density=False)
plt.legend(loc='upper left')
plt.xlabel(r'$\sigma^*$')
plt.ylabel(r'$N(\sigma^*)$')
plt.xlim(0.998, 1.008)
plt.ylim(0, 550)
plt.title('Histogram za sve jackknife uzorke')

plt.subplot(122)
x = np.linspace(0.45, 1.15, 1000)
plt.plot(x, pdf1_jackknife.pdf(x), color='royalblue', ls=':', label=r'$\sigma$', zorder=2)
plt.plot(x, pdf1.pdf(x), color='grey', label=r'$\sigma_s=s/\sqrt{2(N-1)}$', zorder=1)
plt.plot(x, pdf2_jackknife.pdf(x), color='indianred', label=r'$\sigma_G=0.7413\,{\rm IQR}$', zorder=2)
plt.plot(x, pdf2.pdf(x), color='springgreen', label=r'$\sigma_{\sigma_G}=1.06\,s/\sqrt{N}$', zorder=1)
plt.legend(loc='upper left')
plt.xlabel(r'$\sigma$')
plt.ylabel(r'$p(\sigma\,|\,x,I)$')
plt.xlim(0.45, 1.15)
plt.ylim(0, 25)
plt.title('Jackknife')
plt.show()
# Out:
# mu_s = 1.002, sigma_mu_s = 0.0223
# mu_sigmaG = 0.5977, sigma_mu_sigmaG = 0.03138
